# %%
### jogo pedra, papel e tesoura, a partir da jogada 11, a máquina aprende a ganhar do usuário com base nas escolhas das primeiras
# rodadas



import random 

def ativapesos(op,it,wt):
    if it > 10:
        return random.choices(op,weights = wt)[0]
    else:
        return random.choice(op) 
        
user = int(input('Escolha uma opção (1, 2, 3 ou 4): \n 1-Pedra \n 2-Papel \n 3-Tesoura \n 4-Sair'))
options = ['Pedra','Papel','Tesoura']
iteracoes = 1
cadaum = [0,0,0]
if optionuser == 'Pedra':
    cadaum[1]+= 1
if optionuser == 'Papel':
    cadaum[2]+=1
if optionuser == 'Tesoura':
    cadaum[0]+=1
    
weit = list(map(lambda x: x/iteracoes,cadaum))
machine = ativapesos(options,iteracoes,weit)
if user == 4:
    print('Você saiu  do jogo')
else:
    optionuser = options[user-1]
    cadaum[user-1] += 1
    while user != 4:
        if optionuser == 'Pedra' and machine == 'Tesoura':
            
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Você Ganhou'.format(optionuser,machine))

        elif optionuser =='Tesoura' and machine == 'Pedra':    
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Você perdeu'.format(optionuser,machine))

        elif  optionuser == 'Tesoura' and machine == 'Papel': 
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Você Ganhou'.format(optionuser,machine))

        elif optionuser == 'Papel' and machine == 'Tesoura':     
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Você perdeu'.format(optionuser,machine))

        elif optionuser == 'Papel'  and machine == 'Pedra' : 
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Você Ganhou'.format(optionuser,machine))

        elif optionuser == 'Pedra'  and machine == 'Papel' : 
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Você perdeu'.format(optionuser,machine))
            
        elif optionuser == 'Pedra'  and machine == 'Pedra' : 
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Empate'.format(optionuser,machine))
                 
        elif optionuser == 'Papel'  and machine == 'Papel' : 
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Empate'.format(optionuser,machine))
            
        elif optionuser == 'Tesoura'  and machine == 'Tesoura' : 
            print('sua jogada --> {}\n Jogada da máquina --> {} \n Empate'.format(optionuser,machine))     
            

        user = int(input('Escolha uma opção (1, 2, 3 ou 4): \n 1-Pedra \n 2-Papel \n 3-Tesoura \n 4-Sair'))   
        options = ['Pedra','Papel','Tesoura']
        machine = ativapesos(options,iteracoes,weit)
        
        
        if user == 4:
            print('Você saiu  do jogo')
        else:
            optionuser = options[user-1]
            iteracoes +=1
            weit = list(map(lambda x: x*10/iteracoes,cadaum))

            if optionuser == 'Pedra':
                cadaum[1]+= 1
            if optionuser == 'Papel':
                cadaum[2]+=1
            if optionuser == 'Tesoura':
                cadaum[0]+=1
